# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score

# %%
df = pd.read_csv('canada_per_capita_income.csv')

# %%
df.describe()
# Out:
#               year  per capita income (US$)
# count    47.000000                47.000000
# mean   1993.000000             18920.137063
# std      13.711309             12034.679438
# min    1970.000000              3399.299037
# 25%    1981.500000              9526.914515
# 50%    1993.000000             16426.725480
# 75%    2004.500000             27458.601420
# max    2016.000000             42676.468370

# %%
X = df.drop('per capita income (US$)', axis=1)
y = df['per capita income (US$)']
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2,random_state=2)
lr = LinearRegression()
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)
y_pred
# Out:
# array([18602.90731472,  9836.602296  , 33744.7068925 , 13024.34957553,
#        28166.14915331, 34541.64371238, 36135.51735215, 10633.53911588,
#        11430.47593577,   273.3604574 ])

# %%
temp = np.c_[X_test,y_test,y_pred]
temp
# Out:
# array([[ 1993.        , 15875.58673   , 18602.90731472],
#        [ 1982.        ,  9619.438377  ,  9836.602296  ],
#        [ 2012.        , 42665.25597   , 33744.7068925 ],
#        [ 1986.        , 11482.89153   , 13024.34957553],
#        [ 2005.        , 29198.05569   , 28166.14915331],
#        [ 2013.        , 42676.46837   , 34541.64371238],
#        [ 2015.        , 35175.18898   , 36135.51735215],
#        [ 1983.        , 10416.53659   , 10633.53911588],
#        [ 1984.        , 10790.32872   , 11430.47593577],
#        [ 1970.        ,  3399.299037  ,   273.3604574 ]])

# %%
pd.DataFrame(data = temp, columns = ["years", "per capita income(US$)", "predicted per capita income(US$)"] )
# Out:
#     years  per capita income(US$)  predicted per capita income(US$)
# 0  1993.0            15875.586730                      18602.907315
# 1  1982.0             9619.438377                       9836.602296
# 2  2012.0            42665.255970                      33744.706892
# 3  1986.0            11482.891530                      13024.349576
# 4  2005.0            29198.055690                      28166.149153
# 5  2013.0            42676.468370                      34541.643712
# 6  2015.0            35175.188980                      36135.517352
# 7  1983.0            10416.536590                      10633.539116
# 8  1984.0            10790.328720                      11430.475936
# 9  1970.0             3399.299037                        273.360457

# %%
mse_lr = mean_squared_error(y_test,y_pred)

# %%
mse_lr
# Out:
# 16782853.094032794

# %%
r2_lr = r2_score(y_test,y_pred)

# %%
 r2_lr
# Out:
# 0.9152214961669327

# %%
intercept_lr = lr.intercept_
coef_lr = lr.coef_[0]

# %%
 intercept_lr
# Out:
# -1569692.174712619

# %%
coef_lr
# Out:
# 796.9368198832587
